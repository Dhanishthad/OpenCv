# %% [markdown]
# 1. Import Dependencies

# %%
import cv2
import os
import matplotlib.pyplot as plt

# %% [markdown]
# 2. Connecting to your webcam

# %%
cap = cv2.VideoCapture(0)

# %%
#get a fame from the capture device
ret, frame = cap.read()

# %%
ret
# Out:
# True

# %%
frame
# Out:
# array([[[  9,   9,  11],
#         [  9,   9,  10],
#         [  7,   7,   7],
#         ...,
#         [210, 212, 212],
#         [209, 211, 211],
#         [211, 213, 213]],
#
#        [[  9,   9,  11],
#         [  9,   9,  11],
#         [  7,   6,   9],
#         ...,
#         [207, 212, 214],
#         [208, 212, 214],
#         [209, 213, 215]],
#
#        [[  5,   7,   9],
#         [  6,   7,   9],
#         [  7,   6,   9],
#         ...,
#         [207, 212, 215],
#         [208, 212, 214],
#         [208, 212, 214]],
#
#        ...,
#
#        [[163, 163, 154],
#         [163, 160, 150],
#         [165, 160, 149],
#         ...,
#         [ 92, 107, 114],
#         [ 92, 106, 114],
#         [ 95, 109, 117]],
#
#        [[163, 163, 154],
#         [162, 161, 149],
#         [161, 160, 146],
#         ...,
#         [ 92, 106, 116],
#         [ 92, 103, 116],
#         [ 92, 103, 116]],
#
#        [[161, 160, 146],
#         [163, 161, 147],
#         [161, 160, 146],
#         ...,
#         [ 86, 102, 114],
#         [ 90, 103, 116],
#         [ 90, 103, 116]]], dtype=uint8)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
plt.show()

# %%
cap.release()

# %%
def take_photo():
    cap =cv2.VideoCapture(0)
    ret, frame= cap.read()
    cv2.imwrite('webcamphoto.jpeg', frame)
    cap.release()

# %%
take_photo()

# %% [markdown]
# 3. Rendering in real time

# %%
#connect to webcam
cap = cv2.VideoCapture(0)

#loop through every frame until we close our webcam
while cap.isOpened():
    ret, frame =cap.read()

    #show image
    cv2.imshow('webcam', frame)

    if cv2.waitKey(1) & 0xFF== ord('q'):
        break

#relese the webcam
cap.release()

#close all the frames
cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture(0)

# %%
cap.isOpened()
# Out:
# True
